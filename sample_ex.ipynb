# %%
import pandas as pd

# %%
import numpy as np
import os

# %%
df1 = pd.read_csv("IV_data\\Kfd_2025\\Kfd_2025\\kfd_2024-25.csv", encoding="latin1")

# %%
df2= pd.read_csv("IV_data\\New_kd_data\\kd_2025\\KD_2025.csv",encoding="latin1")
# Out:
# C:\Users\VIP\AppData\Local\Temp\ipykernel_19444\469198321.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2= pd.read_csv("IV_data\\New_kd_data\\kd_2025\\KD_2025.csv",encoding="latin1")

# %%
merge= pd.merge(df1,df2,on="vsnr")

# %%
pd.set_option('display.max_columns', None)
merge.head()
# Out:
#            vsnr        logb                phyb  fahrernummer  FZGNR  \
# 0  24514516-008  05.01.2025  06Jan2025:10:27:21             2      1
# 1  24514516-008  05.01.2025  06Jan2025:10:27:21             1      1
# 2  24514728-004  20.03.2025  20Mrz2025:11:44:10             1      1
# 3  24514728-004  20.03.2025  20Mrz2025:11:44:10             1      1
# 4  24514728-004  20.03.2025  20Mrz2025:11:44:10             2      1
#
#    begl_fahren    fs_datum    gebdatum       geschlecht  id_beruf  \
# 0  70732/ nein         NaN  14.09.1997              NaN       NaN
# 1  70732/ nein  08.09.2005  22.06.1987  21205/ männlich       NaN
# 2  70732/ nein  06.03.2003  06.03.1984  21205/ männlich       NaN
# 3  70732/ nein  06.03.2003  06.03.1984  21205/ männlich       NaN
# 4  70732/ nein         NaN  07.02.1987  21204/ weiblich       NaN
#
#             fahrertyp nutzung_andere_fzg     schaeden  schaeden_dritte  \
# 0       06744/ Fahrer        70732/ nein  70732/ nein                0
# ...

# %%
import pickle

# %%
merge.to_csv("Mergesaample.csv",index=False)

# %%
import numpy, pandas, matplotlib, seaborn, plotly, sklearn
print(numpy.__version__, pandas.__version__, matplotlib.__version__, seaborn.__version__, plotly.__version__, sklearn.__version__)

# %%
import pickle

# %%
dd = pd.read_csv('D:\vs_MT\IV_data\Maklerliste Stand 01.03.2025.xlsx')

# %%
dd = pd.read_excel('D:\\vs_MT\\IV_data\\Maklerliste Stand 01.03.2025.xlsx')

# %%
dd.head()

# %%
dd.info()

# %%
dd.dtypes
